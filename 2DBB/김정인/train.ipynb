# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/')

# %%
import time
import torch.backends.cudnn as cudnn
import torch.optim
import torch.utils.data

from Dataset import Dataset

# %%
# Data parameters
data_folder = "/content/drive/MyDrive/data/2DBBs"

# Model parameters
# n_classes = len(label_map)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Learning parameters
checkpoint = None
batch_size = 4
iterations = 10
workers = 4
lr = 1e-3
cudnn.benchmark = True

# %%
train_dataset = Dataset(data_folder,
                        split='training',
                        transform=None)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))

test_dataset = Dataset(data_folder,
                        split='training',
                        transform=None)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
# Out:
# Loading...: 100%|██████████| 800/800 [00:00<00:00, 805048.75it/s]
#
#
# Loading...: 100%|██████████| 800/800 [00:00<00:00, 1081006.19it/s]

# %%
def main():
    global start_epoch, epoch, label_map, checkpoint
    # Initialize model or load checkpoint
    if checkpoint is None:
        start_epoch = 0
        # model = SSD300(n_classes=n_classes)
        bias = list()
        not_biases = list()
